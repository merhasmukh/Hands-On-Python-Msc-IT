# %% [markdown]
# # Core Programming in Python
#
# ## 📖 1. Variables, Constants, and Data Types
#
# In Python, variables are created the moment you first assign a value to them. You don't need to declare their type.
# There are no true "constants" in Python, but by convention, we use ALL_CAPS for variables that shouldn't change.

# %%
print("hi")
# Out:
# hi

# %%
# 1. Variables and Data Types
age = 25                  # int
height = 1.75             # float
name = "Alice"            # str
is_student = True         # bool
nothing = None            # NoneType

# Constants (convention only)
PI = 3.14159

print(name, "is", age, "years old.")
# Output: Alice is 25 years old.
# Out:
# Alice is 25 years old.

# %% [markdown]
# ## 📖 2. Type Checking and Type Casting
#
# You can check the type of a variable using `type()`. You can convert (cast) between types using functions like `int()`, `float()`, `str()`, and `bool()`.

# %%
print(type(age))          # Output: <class 'int'>

# Type Casting
num_str = "100"
num_int = int(num_str)
print(num_int + 50)       # Output: 150

bool_val = bool("0")        # 0 is False, any other number is True
print(bool_val)           # Output: False
# Out:
# <class 'int'>
# 150
# True

# %%
number = "hasmukh"

# %%
number=float(number)
print(number)
# Out:
# 105000.0

# %%
number=bool(number)
print(number)
# Out:
# True

# %%
number=bool(None)
print(number)
# Out:
# False

# %% [markdown]
# ## 📖 3. Input and Output
#
# Use `print()` for output and `input()` for input. Remember that `input()` always returns a string!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)

# %%
user_name = int(input("Enter your name: "))
print("Hello,", user_name)
# Out:
# Hello, 56

# %% [markdown]
# ## 📖 4. String Formatting
#
# Python 3.6+ introduced **f-strings**, which are the preferred way to format strings.

# %%
course = "Python"
version = 3.11

# f-string (Recommended)
print(f"Welcome to {course} {version}!")  # Output: Welcome to Python 3.11!
# Out:
# Welcome to Python 3.11!

# %%
# .format() method
print("Welcome to {} {}!".format(course, version))
# Out:
# Welcome to Python 3.11!

# %%
# Old % style
print("Welcome to %s %.3f!" % (course, version))
# Out:
# Welcome to Python 3.110!

# %% [markdown]
# ## 📖 5. Operators
#
# Python has various operators: arithmetic, comparison, logical, assignment, identity, and membership.

# %%
a = 10
b = 3

print("a // b =", a // b)  # Floor division (Output: 3)
print("a % b =", a % b)    # Modulo (Output: 1)
print("a ** b =", a ** b)  # Exponentiation (Output: 1000)
# Out:
# a // b = 3
# a % b = 1
# a ** b = 1000
# False
# False
# True

# %%
a=36
b=10

# %%
print(a/b)
print(a//b)
# Out:
# 3.6
# 3

# %%
# Logical
print(True and False)      # Output: False

# %%
a=2
b=4
print(a and b)
# Out:
# 4

# %%
a1="hi"
b1="hello"
print(a1 and b1)
# Out:
# hello

# %%
a=0
b="hasmukh"
print(a and b)
print(b and a)
# Out:
# 0
# 0

# %%
print( True and True)
# Out:
# True

# %%
print( True and False)
# Out:
# False

# %%
print( False and False)
# Out:
# False

# %%
print( False and True)
# Out:
# False

# %% [markdown]
# ### Return the first falsy value; if all values are truthy, return the last value.
# - This behavior is called short-circuit evaluation.

# %% [markdown]
# ### 'hi' and 0 and 'hasmukh or 'name'

# %% [markdown]
# ### 'hi' or 0 and 'hasmukh and 'name'

# %%
print('hi' or 0 and 'hasmukh' and 'name')

(hi or 0)and(hasmukh and name )
(hi)and(hasmukh)
hii
# Out:
# hi

# %%
print('hi' or 0 and 'hasmukh' and 'name')

# %%
print('hasmukh' and 'name')
# Out:
# name

# %%
print( False or True)
# Out:
# True

# %%
print( False or True)

# %%
print(not 0)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
print(not None)
# Out:
# True

# %% [markdown]
# ### print(not (5 or 0 and 10 or "hi"))

# %% [markdown]
# ### print(not (5 or (not (5 and 100 or 200 and 500)) and 10 or "hi"))

# %%
print(5 or (not (5 and 100 or 200 and 500)) and 10 or "hi")
# Out:
# 5

# %%
# Identity
x = [1, 2, 3]
y = [1, 2, 3]
print(x is y)              # Output: False (different objects in memory)

# Membership
print(2 in x)              # Output: True

# %% [markdown]
# ## 📖 6. Decision Making
#
# Control the flow of your program with `if`, `elif`, and `else`.

# %%
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
else:
    print("Grade: C")
# Output: Grade: B

# Ternary Operator
result = "Pass" if score >= 50 else "Fail"
print(result) # Output: Pass
# Out:
# Grade: B
# Pass

# %% [markdown]
# ## 📖 7. Loops
#
# Use `for` loops to iterate over a sequence. Use `while` loops to repeat as long as a condition is true.

# %%
# For loop
for i in range(3):
    print(f"For loop iteration: {i}")

# While loop
count = 0
while count < 2:
    print(f"While loop count: {count}")
    count += 1
# Out:
# For loop iteration: 0
# For loop iteration: 1
# For loop iteration: 2
# While loop count: 0
# While loop count: 1

# %% [markdown]
# ## 📖 8. Loop Control
#
# - `break`: Exits the loop entirely
# - `continue`: Skips to the next iteration
# - `pass`: Does nothing (acts as a placeholder)

# %%
for i in range(5):
    if i == 2:
        continue  # Skip 2
    if i == 4:
        break     # Stop at 4
    print(i)
# Output:
# 0
# 1
# 3
# Out:
# 0
# 1
# 3

# %% [markdown]
# ## 📖 9. Built-in Helpers
#
# - `range(start, stop, step)`: Generates a sequence of numbers.
# - `enumerate()`: Adds a counter to an iterable.
# - `zip()`: Combines multiple iterables.

# %%
names = ["Alice", "Bob", "Charlie"]
scores = [85, 90, 95]

# enumerate
for idx, name in enumerate(names, start=1):
    print(f"{idx}. {name}")

# zip
for name, score in zip(names, scores):
    print(f"{name} scored {score}")
# Out:
# 1. Alice
# 2. Bob
# 3. Charlie
# Alice scored 85
# Bob scored 90
# Charlie scored 95

# %% [markdown]
# ## ⚠️ Common Mistakes
# - Forgetting that `input()` returns a string.
# - Confusing `=` (assignment) with `==` (comparison).
# - Off-by-one errors with `range()` (stop value is exclusive).

# %% [markdown]
# ## 🏋️ Exercises
#
# Please check `exercises/02_exercises.py` to practice these concepts!
